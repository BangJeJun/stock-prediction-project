# %% [markdown]
# ## LSTM_use_model2
#
# model1
# - senticle데이터만 + 크롤링 labeling data을 사용
# - 단어 길이 25
#
# 결과
# - 부정 하나 예측함

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -v python-mecab-ko
# Out:
# Using pip 21.1.3 from /usr/local/lib/python3.7/dist-packages/pip (python 3.7)
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.7/UNKNOWN
# sysconfig: /usr/include/python3.7m/UNKNOWN
# Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local
# sysconfig: /usr
# Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Non-user install because site-packages writeable
# Created temporary directory: /tmp/pip-ephem-wheel-cache-_jduw4z3
# Created temporary directory: /tmp/pip-req-tracker-uxcqylsj
# Initialized build tracking at /tmp/pip-req-tracker-uxcqylsj
# Created build tracker: /tmp/pip-req-tracker-uxcqylsj
# Entered build tracker: /tmp/pip-req-tracker-uxcqylsj
# Created temporary directory: /tmp/pip-install-22bhj0kl
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# 2 location(s) to search for versions of python-mecab-ko:
# * https://pypi.org/simple/python-mecab-ko/
# * https://us-python.pkg.dev/colab-wheels/public/simple/python-mecab-ko/
# Fetching project page and analyzing links: https://pypi.org/simple/python-mecab-ko/
# Getting page https://pypi.org/simple/python-mecab-ko/
# Found index url https://pypi.org/simple
# Looking up "https://pypi.org/simple/python-mecab-ko/" in the cache
# Request header has "max_age" as 0, cache bypassed
# Starting new HTTPS connection (1): pypi.org:443
# https://pypi.org:443 "GET /simple/python-mecab-ko/ HTTP/1.1" 200 1538
# Updating cache with response from "https://pypi.org/simple/python-mecab-ko/"
# Caching due to etag
#   Found link https://files.pythonhosted.org/packages/90/de/6686bfe510090832a3fb2b7335d99285e83af1621022e991e19f298ece65/python-mecab-ko-1.0.0.tar.gz#sha256=e5ceee371907ab1061d31377448e706cf5fd1ad562fa6575372ac63948c2e383 (from https://pypi.org/simple/python-mecab-ko/) (requires-python:>=3), version: 1.0.0
#   Found link https://files.pythonhosted.org/packages/85/62/effd3d6bf0fcc679b103def716f71bba632713057f3ab07757f8172851ec/python-mecab-ko-1.0.1.tar.gz#sha256=d8f67cb2c6f0f16f8b252e922fa818bd9444113dca01b7d30884a4d54fddd632 (from https://pypi.org/simple/python-mecab-ko/) (requires-python:>=3), version: 1.0.1
#   Found link https://files.pythonhosted.org/packages/47/5b/4a3cc03939ad6458c29eef4f4372c0dd11d6777eab0186f5a772ef6fcf75/python-mecab-ko-1.0.2.tar.gz#sha256=a90c86faf9672ba0a96050a4be57beac65cf8fac5a3784dc014a8f7b26754acc (from https://pypi.org/simple/python-mecab-ko/) (requires-python:>=3), version: 1.0.2
#   Found link https://files.pythonhosted.org/packages/5f/34/9a5064bd98097b0562d56ca042a7bd76c43f391d05a335264eb8852857b8/python-mecab-ko-1.0.4.tar.gz#sha256=6f728497aa01c0a91fea3a659fcc97f87275b031ab9c6d71c3e8f572d8af2e02 (from https://pypi.org/simple/python-mecab-ko/) (requires-python:>=3), version: 1.0.4
#   Found link https://files.pythonhosted.org/packages/74/c3/4ffb56ca0b6e6297dab600043684bb38b4aa8cd012dc8b6ccc1cdadbe1d1/python-mecab-ko-1.0.5.tar.gz#sha256=172c6f2e5ad3f162bf3b72867f998dbde1ac0400e65af90bba06a7244b20fa90 (from https://pypi.org/simple/python-mecab-ko/) (requires-python:>=3), version: 1.0.5
#   Found link https://files.pythonhosted.org/packages/ac/7f/88af78847b799099cd97f40a25d7ac18d2a88c1d73c8e9080476f6e86a75/python-mecab-ko-1.0.6.tar.gz#sha256=c7fcfb41e01d617d1253ac69a575eb659e3bbdf9f9cb990d5de134e5025455f8 (from https://pypi.org/simple/python-mecab-ko/) (requires-python:>=3), version: 1.0
# Skipping link: not a file: https://pypi.org/simple/python-mecab-ko/
# Given no hashes to check 14 links for project 'python-mecab-ko': discarding no candidates
# Collecting python-mecab-ko
#   Created temporary directory: /tmp/pip-unpack-l24s6c8x
#   Looking up "https://files.pythonhosted.org/packages/c4/f7/f1de6565a5984a6ea483ae74c95c2e607697e8aae2babe5d47dfdc78ec42/python-mecab-ko-1.0.14.tar.gz" in the cache
#   No cache entry available
#   Starting new HTTPS connection (1): files.pythonhosted.org:443
#   https://files.pythonhosted.org:443 "GET /packages/c4/f7/f1de6565a5984a6ea483ae74c95c2e607697e8aae2babe5d47dfdc78ec42/python-mecab-ko-1.0.14.tar.gz HTTP/1.1" 200 9616
#   Downloading python-mecab-ko-1.0.14.tar.gz (9.6 kB)
#   Ignoring unknown cache-control directive: immutable
#   Updating cache with response from "https://files.pythonhosted.org/packages/c4/f7/f1de6565a5984a6ea483ae74c95c2e607697e8aae2babe5d47dfdc78ec42/python-mecab-ko-1.0.14.tar.gz"
#   Caching due to etag
#   Added python-mecab-ko from https://files.pythonhosted.org/packages/c4/f7/f1de6565a5984a6ea483ae74c95c2e607697e8aae2babe5d47dfdc78ec42/python-mecab-ko-1.0.14.tar.gz#sha256=5f79dc0ede7eeb4bb4e39689976afa508782f3226fc0a4250d0c1db1f799d732 to build tracker '/tmp/pip-req-tracker-uxcqylsj'
#     Running setup.py (path:/tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8/setup.py) egg_info for package python-mecab-ko
#     Created temporary directory: /tmp/pip-pip-egg-info-ekv3xjut
#     Running command python setup.py egg_info
#     running egg_info
#     creating /tmp/pip-pip-egg-info-ekv3xjut/python_mecab_ko.egg-info
#     writing /tmp/pip-pip-egg-info-ekv3xjut/python_mecab_ko.egg-info/PKG-INFO
#     writing dependency_links to /tmp/pip-pip-egg-info-ekv3xjut/python_mecab_ko.egg-info/dependency_links.txt
#     writing requirements to /tmp/pip-pip-egg-info-ekv3xjut/python_mecab_ko.egg-info/requires.txt
#     writing top-level names to /tmp/pip-pip-egg-info-ekv3xjut/python_mecab_ko.egg-info/top_level.txt
#     writing manifest file '/tmp/pip-pip-egg-info-ekv3xjut/python_mecab_ko.egg-info/SOURCES.txt'
#     reading manifest file '/tmp/pip-pip-egg-info-ekv3xjut/python_mecab_ko.egg-info/SOURCES.txt'
#     adding license file 'LICENSE'
#     writing manifest file '/tmp/pip-pip-egg-info-ekv3xjut/python_mecab_ko.egg-info/SOURCES.txt'
#   Source in /tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8 has version 1.0.14, which satisfies requirement python-mecab-ko from https://files.pythonhosted.org/packages/c4/f7/f1de6565a5984a6ea483ae74c95c2e607697e8aae2babe5d47dfdc78ec42/python-mecab-ko-1.0.14.tar.gz#sha256=5f79dc0ede7eeb4bb4e39689976afa508782f3226fc0a4250d0c1db1f799d732
#   Removed python-mecab-ko from https://files.pythonhosted.org/packages/c4/f7/f1de6565a5984a6ea483ae74c95c2e607697e8aae2babe5d47dfdc78ec42/python-mecab-ko-1.0.14.tar.gz#sha256=5f79dc0ede7eeb4bb4e39689976afa508782f3226fc0a4250d0c1db1f799d732 from build tracker '/tmp/pip-req-tracker-uxcqylsj'
# 2 location(s) to search for versions of pybind11:
# * https://pypi.org/simple/pybind11/
# * https://us-python.pkg.dev/colab-wheels/public/simple/pybind11/
# Fetching project page and analyzing links: https://pypi.org/simple/pybind11/
# Getting page https://pypi.org/simple/pybind11/
# Found index url https://pypi.org/simple
# Looking up "https://pypi.org/simple/pybind11/" in the cache
# Request header has "max_age" as 0, cache bypassed
# https://pypi.org:443 "GET /simple/pybind11/ HTTP/1.1" 200 7714
# Updating cache with response from "https://pypi.org/simple/pybind11/"
# Caching due to etag
#   Found link https://files.pythonhosted.org/packages/df/90/4f0068ca5e0c0ef1d0cbcc1fd4c1ecea664c8b995726c5254619a38baafb/pybind11-1.0-py2.py3-none-any.whl#sha256=b1ab3a180bec0e31a965d4070b25a8df651f90dccc406f1e041f6fb0c20a5a5c (from https://pypi.org/simple/pybind11/), version: 1.0
#   Found link https://files.pythonhosted.org/packages/ee/1d/75e412725a95ef00226af81a2562956989689df73d374d3fc7eb65edad51/pybind11-1.0.tar.gz#sha256=cdd3249114af4a97120bc72645b209e90fe6c654a6903824ae9e1b6b76dd4f47 (from https://pypi.org/simple/pybind11/), version: 1.0
#   Found link https://files.pythonhosted.org/packages/91/6d/b0f6fc3f8f4c457dae1f67a0a5f506fee5e8366fe9b41bab62aa48f9abdb/pybind11-1.2-py2.py3-none-any.whl#sha256=b8be7525d8957b009859c5be3121c3f4055878df47b9af4d5987634784bcd8cd (from https://pypi.org/simple/pybind11/), version: 1.2
#   Found link https://files.pythonhosted.org/packages/3f/29/9a9b11c9ae144ee042502bf81658f9387d1ea7fcbbe09ef84651143d2439/pybind11-1.2.tar.gz#sha256=6e5abc9a4549ca6307b81301a558eb60e2c78028b2f258b1adef9f3b45de738b (from https://pypi.org/simple/pybind11/), version: 1.2
#   Found link https://files.pythonhosted.org/packages/40/39/1fb04919dbae11ea3b0e3630abc3d0a88cb63cdf4c73e4c2fe2b0ded982e/pybind11-1.3-py2.py3-none-any.whl#sha256=c5d64e962ff7df3d0e1dd94c90f53022b733b24257eb7c39a4057ad7ad96a8df (from https://pypi.org/simple/pybind11/), version: 1.3
#   Found link https://files.pythonhosted.org/packages/51/1e/d1c8bfd14b98ba27f1c3f9cb2f58c293cb48be32263519ecc6c9eaebaf0a/pybind11-1.3.tar.gz#sha256=c829bb9ff9267917efab027f6f3cb4e4955c50a4c3ebed9f00c58684b2e5a0a0 (from https://pypi.org/simple/pybind11/), version: 1.3
#   Found link https://files.pythonhosted.org/packages/4b/9c/6551641ee8e216d49129bead63584e0e2f1d18663a171b59bb1a0ab487b2/pybind11-1.4-py2.py3-none-any.whl#sha256=3508dffe1de53217371ff412c9f222b9dd41d04f550c80b79b873cd2979b6316 (from https://pypi.org/simple/pybind11/), version: 1.4
from https://pypi.org/simple/pybind11/) (requires-python:!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*,>=2.7), version: 2.9.2
#   Found link https://files.pythonhosted.org/packages/cf/6a/a7f2c40fdb43fcf59bc1eebb0a4c4206a99ccddee6391a1168fa6efebce9/pybind11-2.9.2.tar.gz#sha256=e5541f8bccf9111d1a94f7897593b55c4cf1a28d5e8cfc8225a855651f011071 (from https://pypi.org/simple/pybind11/) (requires-python:!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*,>=2.7), version: 2.9.2
#   Found link https://files.pythonhosted.org/packages/9a/7f/855560aa568e50bea6012ed535e6b8c436e99394f3e5a649d44d2e557242/pybind11-2.10.0-py3-none-any.whl#sha256=6bbc7a2f79689307f0d8d240172851955fc214b33e4cbd7fdbc9cd7176a09260 (from https://pypi.org/simple/pybind11/) (requires-python:>=3.6), version: 2.10.0
#   Found link https://files.pythonhosted.org/packages/59/f6/aafe0b7e798f25632b199523cce98552fde53e8c552b9d96765426532d5f/pybind11-2.10.0.tar.gz#sha256=18977589c10f595f65ec1be90b0a0763b43e458d25d97be9db75b958eb1f43fe (from https://pypi.org/simple/pybind11/) (requires-python:>=3.6), version: 2.10.0
#   Found link https://files.pythonhosted.org/packages/1d/53/e6b27f3596278f9dd1d28ef1ddb344fd0cd5db98ef2179d69a2044e11897/pybind11-2.10.1-py3-none-any.whl#sha256=ebf3eeac46859a2e10077ae45378ba3f33d999a9064697a3464fba1a4a04fc0a (from https://pypi.org/simple/pybind11/) (requires-python:>=3.6), version: 2.10.1
#   Found link https://files.pythonhosted.org/packages/2f/23/aaf147a5bc31c8be286f07d862b3699d7b49e3411fb75087525b5c31ab3e/pybind11-2.10.1.tar.gz#sha256=c9571b8a6607c8e90ea156a2a455383b9911f89da414e9f5e251ab58dc3e3c71 (from https://pypi.org/simple/pybind11/) (requires-python:>=3.6), version: 2.10.1
# Fetching project page and analyzing links: https://us-python.pkg.dev/colab-wheels/public/simple/pybind11/
# Getting page https://us-python.pkg.dev/colab-wheels/public/simple/pybind11/
# Found index url https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking up "https://us-python.pkg.dev/colab-wheels/public/simple/pybind11/" in the cache
# Request header has "max_age" as 0, cache bypassed
# https://us-python.pkg.dev:443 "GET /colab-wheels/public/simple/pybind11/ HTTP/1.1" 404 32
# Status code 404 not in (200, 203, 300, 301)
# Could not fetch URL https://us-python.pkg.dev/colab-wheels/public/simple/pybind11/: 404 Client Error: Not Found for url: https://us-python.pkg.dev/colab-wheels/public/simple/pybind11/ - skipping
# Skipping link: not a file: https://us-python.pkg.dev/colab-wheels/public/simple/pybind11/
# Skipping link: not a file: https://pypi.org/simple/pybind11/
# Given no hashes to check 6 links for project 'pybind11': discarding no candidates
# Collecting pybind11~=2.9.0
#   Created temporary directory: /tmp/pip-unpack-ua46tzs1
#   Looking up "https://files.pythonhosted.org/packages/fd/24/efc9e62aa1baa48622028c59ae2c70fa134801e8acbdf30e5b594fe5a360/pybind11-2.9.2-py2.py3-none-any.whl" in the cache
#   No cache entry available
#   https://files.pythonhosted.org:443 "GET /packages/fd/24/efc9e62aa1baa48622028c59ae2c70fa134801e8acbdf30e5b594fe5a360/pybind11-2.9.2-py2.py3-none-any.whl HTTP/1.1" 200 213602
#   Downloading pybind11-2.9.2-py2.py3-none-any.whl (213 kB)
#      |██████████████████████████████▊ | 204 kB 5.1 MB/s eta 0:00:01  Ignoring unknown cache-control directive: immutable
#   Updating cache with response from "https://files.pythonhosted.org/packages/fd/24/efc9e62aa1baa48622028c59ae2c70fa134801e8acbdf30e5b594fe5a360/pybind11-2.9.2-py2.py3-none-any.whl"
#   Caching due to etag
#      |████████████████████████████████| 213 kB 5.1 MB/s
#   Added pybind11~=2.9.0 from https://files.pythonhosted.org/packages/fd/24/efc9e62aa1baa48622028c59ae2c70fa134801e8acbdf30e5b594fe5a360/pybind11-2.9.2-py2.py3-none-any.whl#sha256=20f56674da31c96bca7569b91e60f2bd30d693f0728541412ec927574f7bc9df (from python-mecab-ko) to build tracker '/tmp/pip-req-tracker-uxcqylsj'
#   Removed pybind11~=2.9.0 from https://files.pythonhosted.org/packages/fd/24/efc9e62aa1baa48622028c59ae2c70fa134801e8acbdf30e5b594fe5a360/pybind11-2.9.2-py2.py3-none-any.whl#sha256=20f56674da31c96bca7569b91e60f2bd30d693f0728541412ec927574f7bc9df (from python-mecab-ko) from build tracker '/tmp/pip-req-tracker-uxcqylsj'
# Created temporary directory: /tmp/pip-unpack-5u2ivjji
# Building wheels for collected packages: python-mecab-ko
#   Created temporary directory: /tmp/pip-wheel-d7uezepp
#   Building wheel for python-mecab-ko (setup.py) ...   Destination directory: /tmp/pip-wheel-d7uezepp
#   Running command /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8/setup.py'"'"'; __file__='"'"'/tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-d7uezepp
#   running bdist_wheel
#   running build
#   running build_py
#   Generating grammar tables from /usr/lib/python3.7/lib2to3/Grammar.txt
#   Generating grammar tables from /usr/lib/python3.7/lib2to3/PatternGrammar.txt
#   creating build
#   creating build/lib.linux-x86_64-3.7
#   creating build/lib.linux-x86_64-3.7/mecab
#   copying mecab/__init__.py -> build/lib.linux-x86_64-3.7/mecab
#   copying mecab/mecab.py -> build/lib.linux-x86_64-3.7/mecab
#   running build_ext
#   creating tmp
#   x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.7m -c /tmp/tmpsw5it3lh.cpp -o tmp/tmpsw5it3lh.o -std=c++14
#   x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.7m -c /tmp/tmpsimorgf3.cpp -o tmp/tmpsimorgf3.o -fvisibility=hidden
#   building '_mecab' extension
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8/setup.py", line 179, in <module>
#       'build_ext': BuildExtensionCommand
#     File "/usr/local/lib/python3.7/dist-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/usr/lib/python3.7/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/usr/lib/python3.7/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/usr/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/usr/local/lib/python3.7/dist-packages/wheel/bdist_wheel.py", line 325, in run
#       self.run_command("build")
#     File "/usr/lib/python3.7/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/usr/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/usr/lib/python3.7/distutils/command/build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "/usr/lib/python3.7/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/usr/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/usr/local/lib/python3.7/dist-packages/setuptools/command/build_ext.py", line 79, in run
#       _build_ext.run(self)
#     File "/usr/local/lib/python3.7/dist-packages/Cython/Distutils/old_build_ext.py", line 186, in run
#       _build_ext.build_ext.run(self)
#     File "/usr/lib/python3.7/distutils/command/build_ext.py", line 340, in run
#       self.build_extensions()
#     File "/tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8/setup.py", line 43, in build_extensions
#       super().build_extensions()
#     File "/usr/local/lib/python3.7/dist-packages/Cython/Distutils/old_build_ext.py", line 195, in build_extensions
#       _build_ext.build_ext.build_extensions(self)
#     File "/usr/lib/python3.7/distutils/command/build_ext.py", line 449, in build_extensions
#       self._build_extensions_serial()
#     File "/usr/lib/python3.7/distutils/command/build_ext.py", line 474, in _build_extensions_serial
#       self.build_extension(ext)
#     File "/usr/local/lib/python3.7/dist-packages/setuptools/command/build_ext.py", line 202, in build_extension
#       _build_ext.build_extension(self, ext)
#     File "/usr/lib/python3.7/distutils/command/build_ext.py", line 534, in build_extension
#       depends=ext.depends)
#     File "/usr/lib/python3.7/distutils/ccompiler.py", line 566, in compile
#       depends, extra_postargs)
#     File "/usr/lib/python3.7/distutils/ccompiler.py", line 341, in _setup_compile
#       pp_opts = gen_preprocess_options(macros, incdirs)
#     File "/usr/lib/python3.7/distutils/ccompiler.py", line 1076, in gen_preprocess_options
#       pp_opts.append("-I%s" % dir)
#     File "/tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8/setup.py", line 95, in __str__
#       return func(*self.args, **self.kwargs)
#     File "/tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8/setup.py", line 108, in get_pybind_include
#       import pybind11
#   ModuleNotFoundError: No module named 'pybind11'
# error
#   ERROR: Failed building wheel for python-mecab-ko
#   Running setup.py clean for python-mecab-ko
#   Running command /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8/setup.py'"'"'; __file__='"'"'/tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#   running clean
#   removing 'build/lib.linux-x86_64-3.7' (and everything under it)
#   'build/bdist.linux-x86_64' does not exist -- can't clean it
#   'build/scripts-3.7' does not exist -- can't clean it
#   removing 'build'
# Failed to build python-mecab-ko
# Installing collected packages: pybind11, python-mecab-ko
#   Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/include/python3.7/pybind11
#   sysconfig: /usr/include/python3.7m/pybind11
#   Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/bin
#   sysconfig: /usr/bin
#   Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local
#   sysconfig: /usr
#   Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = None
#
#   changing mode of /usr/local/bin/pybind11-config to 755
#   Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/lib/python3.7/dist-packages
#   sysconfig: /usr/lib/python3.7/site-packages
#   Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/include/python3.7/python-mecab-ko
#   sysconfig: /usr/include/python3.7m/python-mecab-ko
#   Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local/bin
#   sysconfig: /usr/bin
#   Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
#   distutils: /usr/local
#   sysconfig: /usr
#   Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = None
#   Created temporary directory: /tmp/pip-record-kt3azpv_
#     Running command /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8/setup.py'"'"'; __file__='"'"'/tmp/pip-install-22bhj0kl/python-mecab-ko_7ec75d710a054abfb5aff85545b6b3e8/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-kt3azpv_/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7/python-mecab-ko
#     running install
#     --2022-11-26 06:07:32--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
#     Resolving bitbucket.org (bitbucket.org)... 18.205.93.1, 18.205.93.2, 18.205.93.0, ...
#     Connecting to bitbucket.org (bitbucket.org)|18.205.93.1|:443... connected.
#     HTTP request sent, awaiting response... 302 Found
# ...
#     emitting matrix      :  12% |#####                                      |
#     emitting matrix      :  13% |#####                                      |
#     emitting matrix      :  14% |######                                     |
#     emitting matrix      :  15% |######                                     |
#     emitting matrix      :  16% |######                                     |
#     emitting matrix      :  17% |#######                                    |
#     emitting matrix      :  18% |#######                                    |
#     emitting matrix      :  19% |########                                   |
#     emitting matrix      :  20% |########                                   |
#     emitting matrix      :  21% |#########                                  |
#     emitting matrix      :  22% |#########                                  |
#     emitting matrix      :  23% |#########                                  |
#     emitting matrix      :  24% |##########                                 |
#     emitting matrix      :  25% |##########                                 |
#     emitting matrix      :  26% |###########                                |
#     emitting matrix      :  27% |###########                                |
#     emitting matrix      :  28% |############                               |
#     emitting matrix      :  29% |############                               |
#     emitting matrix      :  30% |############                               |
#     emitting matrix      :  31% |#############                              |
#     emitting matrix      :  32% |#############                              |
#     emitting matrix      :  33% |##############                             |
#     emitting matrix      :  34% |##############                             |
#     emitting matrix      :  35% |###############                            |
#     emitting matrix      :  36% |###############                            |
#     emitting matrix      :  37% |###############                            |
#     emitting matrix      :  38% |################                           |
#     emitting matrix      :  39% |################                           |
#     emitting matrix      :  40% |#################                          |
#     emitting matrix      :  41% |#################                          |
#     emitting matrix      :  42% |##################                         |
#     emitting matrix      :  43% |##################                         |
#     emitting matrix      :  44% |##################                         |
#     emitting matrix      :  45% |###################                        |
#     emitting matrix      :  46% |###################                        |
#     emitting matrix      :  47% |####################                       |
#     emitting matrix      :  48% |####################                       |
#     emitting matrix      :  49% |#####################                      |
#     emitting matrix      :  50% |#####################                      |
#     emitting matrix      :  51% |#####################                      |
#     emitting matrix      :  52% |######################                     |
#     emitting matrix      :  53% |######################                     |
#     emitting matrix      :  54% |#######################                    |
#     emitting matrix      :  55% |#######################                    |
#     emitting matrix      :  56% |########################                   |
#     emitting matrix      :  57% |########################                   |
#     emitting matrix      :  58% |########################                   |
#     emitting matrix      :  59% |#########################                  |
#     emitting matrix      :  60% |#########################                  |
#     emitting matrix      :  61% |##########################                 |
#     emitting matrix      :  62% |##########################                 |
#     emitting matrix      :  63% |###########################                |
#     emitting matrix      :  64% |###########################                |
#     emitting matrix      :  65% |###########################                |
#     emitting matrix      :  66% |############################               |
#     emitting matrix      :  67% |############################               |
#     emitting matrix      :  68% |#############################              |
#     emitting matrix      :  69% |#############################              |
#     emitting matrix      :  70% |##############################             |
#     emitting matrix      :  71% |##############################             |
#     emitting matrix      :  72% |##############################             |
#     emitting matrix      :  73% |###############################            |
#     emitting matrix      :  74% |###############################            |
#     emitting matrix      :  75% |################################           |
#     emitting matrix      :  76% |################################           |
#     emitting matrix      :  77% |#################################          |
#     emitting matrix      :  78% |#################################          |
#     emitting matrix      :  79% |#################################          |
#     emitting matrix      :  80% |##################################         |
#     emitting matrix      :  81% |##################################         |
#     emitting matrix      :  82% |###################################        |
#     emitting matrix      :  83% |###################################        |
#     emitting matrix      :  84% |####################################       |
#     emitting matrix      :  85% |####################################       |
#     emitting matrix      :  86% |####################################       |
#     emitting matrix      :  87% |#####################################      |
#     emitting matrix      :  88% |#####################################      |
#     emitting matrix      :  89% |######################################     |
#     emitting matrix      :  90% |######################################     |
#     emitting matrix      :  91% |#######################################    |
#     emitting matrix      :  92% |#######################################    |
#     emitting matrix      :  93% |#######################################    |
#     emitting matrix      :  94% |########################################   |
#     emitting matrix      :  95% |########################################   |
#     emitting matrix      :  96% |#########################################  |
#     emitting matrix      :  97% |#########################################  |
#     emitting matrix      :  98% |########################################## |
#     emitting matrix      :  99% |########################################## |
#     emitting matrix      : 100% |###########################################|
#
#     done!
#     echo To enable dictionary, rewrite /usr/etc/mecabrc as \"dicdir = /usr/lib/mecab/dic/mecab-ko-dic\"
#     To enable dictionary, rewrite /usr/etc/mecabrc as "dicdir = /usr/lib/mecab/dic/mecab-ko-dic"
#     make[1]: Entering directory '/tmp/tmp9g1kz9r8/mecab-ko-dic-2.1.1-20180720'
#     make[1]: Nothing to be done for 'install-exec-am'.
#      /bin/mkdir -p '/usr/lib/mecab/dic/mecab-ko-dic'
#      /usr/bin/install -c -m 644 model.bin matrix.bin char.bin sys.dic unk.dic left-id.def right-id.def rewrite.def pos-id.def dicrc '/usr/lib/mecab/dic/mecab-ko-dic'
#     make[1]: Leaving directory '/tmp/tmp9g1kz9r8/mecab-ko-dic-2.1.1-20180720'
#     Installing mecab-ko...
#     Installing mecab-ko-dic...
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.7
#     creating build/lib.linux-x86_64-3.7/mecab
#     copying mecab/__init__.py -> build/lib.linux-x86_64-3.7/mecab
#     copying mecab/mecab.py -> build/lib.linux-x86_64-3.7/mecab
#     running build_ext
#     x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.7m -c /tmp/tmpz_v_len6.cpp -o tmp/tmpz_v_len6.o -std=c++14
#     x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.7m -c /tmp/tmppgzktlxe.cpp -o tmp/tmppgzktlxe.o -fvisibility=hidden
#     building '_mecab' extension
#     creating build/temp.linux-x86_64-3.7
#     creating build/temp.linux-x86_64-3.7/mecab
#     creating build/temp.linux-x86_64-3.7/mecab/pybind
#     creating build/temp.linux-x86_64-3.7/mecab/pybind/_mecab
#     x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/include -I/usr/include/python3.7m -c mecab/pybind/_mecab/node.cpp -o build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/node.o -DVERSION_INFO="1.0.14" -std=c++14 -fvisibility=hidden
#     x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/include -I/usr/include/python3.7m -c mecab/pybind/_mecab/path.cpp -o build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/path.o -DVERSION_INFO="1.0.14" -std=c++14 -fvisibility=hidden
#     x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/include -I/usr/include/python3.7m -c mecab/pybind/_mecab/lattice.cpp -o build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/lattice.o -DVERSION_INFO="1.0.14" -std=c++14 -fvisibility=hidden
#     x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/include -I/usr/include/python3.7m -c mecab/pybind/_mecab/dictionaryinfo.cpp -o build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/dictionaryinfo.o -DVERSION_INFO="1.0.14" -std=c++14 -fvisibility=hidden
#     x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/include -I/usr/include/python3.7m -c mecab/pybind/_mecab/tagger.cpp -o build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/tagger.o -DVERSION_INFO="1.0.14" -std=c++14 -fvisibility=hidden
#     x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/local/lib/python3.7/dist-packages/pybind11/include -I/usr/include -I/usr/include/python3.7m -c mecab/pybind/_mecab/_mecab.cpp -o build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/_mecab.o -DVERSION_INFO="1.0.14" -std=c++14 -fvisibility=hidden
#     x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 -Wl,-Bsymbolic-functions -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/node.o build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/path.o build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/lattice.o build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/dictionaryinfo.o build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/tagger.o build/temp.linux-x86_64-3.7/mecab/pybind/_mecab/_mecab.o -L/usr/lib -Wl,--enable-new-dtags,-R/usr/lib -lmecab -o build/lib.linux-x86_64-3.7/_mecab.cpython-37m-x86_64-linux-gnu.so
#     running install_lib
#     copying build/lib.linux-x86_64-3.7/_mecab.cpython-37m-x86_64-linux-gnu.so -> /usr/local/lib/python3.7/dist-packages
#     creating /usr/local/lib/python3.7/dist-packages/mecab
#     copying build/lib.linux-x86_64-3.7/mecab/__init__.py -> /usr/local/lib/python3.7/dist-packages/mecab
#     copying build/lib.linux-x86_64-3.7/mecab/mecab.py -> /usr/local/lib/python3.7/dist-packages/mecab
#     byte-compiling /usr/local/lib/python3.7/dist-packages/mecab/__init__.py to __init__.cpython-37.pyc
#     byte-compiling /usr/local/lib/python3.7/dist-packages/mecab/mecab.py to mecab.cpython-37.pyc
#     running install_data
#     creating /usr/local/scripts
#     copying scripts/install-mecab-ko.py -> /usr/local/scripts
#     running install_egg_info
#     running egg_info
#     writing python_mecab_ko.egg-info/PKG-INFO
#     writing dependency_links to python_mecab_ko.egg-info/dependency_links.txt
#     writing requirements to python_mecab_ko.egg-info/requires.txt
#     writing top-level names to python_mecab_ko.egg-info/top_level.txt
#     reading manifest file 'python_mecab_ko.egg-info/SOURCES.txt'
#     adding license file 'LICENSE'
#     writing manifest file 'python_mecab_ko.egg-info/SOURCES.txt'
#     Copying python_mecab_ko.egg-info to /usr/local/lib/python3.7/dist-packages/python_mecab_ko-1.0.14-py3.7.egg-info
#     running install_scripts
#     writing list of installed files to '/tmp/pip-record-kt3azpv_/install-record.txt'
#     Running setup.py install for python-mecab-ko ... done
#   DEPRECATION: python-mecab-ko was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. A possible replacement is to fix the wheel build issue reported above. You can find discussion regarding this at https://github.com/pypa/pip/issues/8368.
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.7/UNKNOWN
# sysconfig: /usr/include/python3.7m/UNKNOWN
# Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local
# sysconfig: /usr
# Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Successfully installed pybind11-2.9.2 python-mecab-ko-1.0.14
# Removed build tracker: '/tmp/pip-req-tracker-uxcqylsj'

# %%
import pandas as pd
import numpy as np
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

## 모델 불러오기
from tensorflow.python.keras.models import load_model
model = load_model('/content/drive/MyDrive/경희대/KHUDA/데비_프로젝트/LSTM/lstm_model_3.h5')
model.summary()

## 뉴스 기사 제목 불러오기
news_df = pd.read_csv('/content/drive/MyDrive/경희대/KHUDA/데비_프로젝트/데이터/samsung_news.csv')
news_df=news_df[['title']]

import mecab
mecab = mecab.MeCab()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 25)          180975
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 64)                23040
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 204,210
# Trainable params: 204,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sent_predict (news_df):
  news_df['title'] = [re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]',' ',s) for s in news_df['title']] # 한국어만 남기고 싶으면
  news_df['token'] = news_df['title'].apply(mecab.morphs)
  # 불용어 제거
  news_df['remove_stopwords'] = None
  stopwords = ['유로','라고','밝혔','대한','명','된다','부터','에게','등','리','관한','드','한다고','몇','코네','던','노','비','았','입니다','할','적','습니다','는다','니','저','로','것','핀란드','만','어','및','다고','고','된','될','약','게','며','지','합니다','아','또','때','겠','뿐','고','있','수','하','기','년','인','되','면','한다','에서','그','했','다','을','의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']
  for i in range(len(news_df)):
    stopwords_removed_sentence = [word for word in news_df.iloc[i,1] if not word in stopwords] # 불용어 제거
    news_df['remove_stopwords'][i] = stopwords_removed_sentence
    input_news = news_df['remove_stopwords']

  tokenizer = Tokenizer()
  tokenizer.fit_on_texts(input_news)
  # 정수 인코딩
  input_news_encoded = tokenizer.texts_to_sequences(input_news)

  # 단어 길이 25으로 padding
  max_len = 25
  pad_new = pad_sequences(input_news_encoded, maxlen = max_len)
  score = model.predict(pad_new)

  news_df['predict'] = None
  news_df['prob'] = None

  for i in range(len(news_df)):
    if score[i].argmax() == 0:
      sent_predict = 0
      prob = ("{:.2f}% 확률로 중성 리뷰입니다.\n".format(score[i][0]/sum(score[i]) * 100))
      news_df['predict'][i] = sent_predict
      news_df['prob'][i] = prob
    elif score[i].argmax() == 1:
      sent_predict = 1
      prob = ("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score[i][1]/sum(score[i]) * 100))
      news_df['predict'][i] = sent_predict
      news_df['prob'][i] = prob
    elif score[i].argmax() == 2:
      sent_predict = 2
      prob = ("{:.2f}% 확률로 부정 리뷰입니다.\n".format(score[i][2]/sum(score[i]) * 100))
      news_df['predict'][i] = sent_predict
      news_df['prob'][i] = prob

  return news_df

# %%
sent_predict(news_df)
# Out:
#                                              title  \
# 0                  삼성 준법위 사업지원    회동 콘트롤타워 부활 논의했나
# 1                   삼성전자  장애인 직원 채용 자회사 만든다 일자리 창출
# 2                         삼성전자  자회사형 장애인 표준사업장 만든다
# 3                       한국남동발전 삼성전자   탄소중립  함께 달린다
# 4                   삼성 임원들  격려금    억 모아 헌혈버스  대 기부
# 5           삼성전자 찾은 민주당   기업  미 중 패권 희생양 안되도록 할 것
# 6                       세계  등 한국제품 몇개일까  삼성전자가 올킬
# 7               국내    대기업 내 여성 임원     명 돌파 삼성전자 최다
# 8          삼성  대한적십자사에  헌혈버스   대 기증 이재용  동행 철학  실천
# 9                   세계    위면 뭐하나  창고에 쌓이는 삼성
# 10                       삼성  저격  삼성생명법    년 만의 부활
# 11                세계에서 팔린     대 중  대는 삼성 누적 점유율  위
# 12               삼성전자   식품관     만 방문  기념 고객 감사 기획전
# 13             품질경영대회 은탑훈장에      년  위 삼성전자 김형남 부사장
# 14     삼성     글로벌 점유율  위     는   년 연속       왕좌  예약
# 15              삼성전자  메모리 한파에 세계 반도체  위 자리 인텔에 내줬다
# 16          농협은행   김치의 날  맞아 삼성전자와 김장 및 쌀 나눔 행사 실시
# 17               번 돈 절반 썼다  삼성    롯데 대기업도 줄줄이  비명
# 18                  민주  삼성전자 공장 방문 미중 경쟁 산업계 전략 점검
# 19          삼성 네오             유럽    기기 보안 표준 인증 획득
# 20                애플  삼성전자 낸드플래시 도입 가능성      견제 영향
# 21              삼성 경계현이 주목한 자이스       억         투자
# 22              민주당 민생대책위  반도체 경쟁 살얼음판 삼성전자 역할 중요
# 23            삼성 저격수  박용진이 발의한  삼성생명법  정무위 법안소위 상정
# 24                 블랙프라이데이 맞아 삼성     북미    판촉  사활
# 25     단독   최고 속도 최저 전력  삼성전자    년 공들인 차세대   램  공개
# 26      종합    강세에도 전 세계 휩쓴        삼성     점유율 절반 차지
# 27                 믿었던 서버용 메모리마저   삼성     반도체 혹한기
# 28                년 더 일했는데 신입 연봉이랑 같다니   삼성 직원의 분노
# 29                 반도체 치킨게임    삼성전자   하이닉스  왜 달라지나
# 30                   애플과 경쟁 와중에 유럽서 샤오미에 추격당하는 삼성폰
# 31     삼성전자  세계    시장 점유율    로  위 수성  프리미엄 부문서 선전
# 32                   박용진  삼성 이재용  아버지 시대의 유물 정리해야
# 33             삼성     경기 침체에도 글로벌    시장 점유율     위
# 34              경제  외치는 민주  삼성   미중 경쟁 희생양 않도록 최선
# 35               삼성전자   자회사형 장애인 표준사업장  설립해 일자리 창출
# 36                  파운드리 반전 신호탄 쏜 삼성  거물급  고객 확보했다
# 37                   다시 등장한  삼성생명 법   국회 통과 여부에 주목
# 38                         남동발전 삼성전자   탄소중립  공동 대응
# 39                        불황 덮친 글로벌   시장 삼성   는 선전
# 40                             해묵은  삼성생명법  또 꺼낸 국회
# 41               삼성       년 연속 글로벌  위 수성   도  위 유지
# 42                  불황에도 삼성     전 세계 시장점유율    위 차지
# 43                 삼성전자  구글 제치고  글로벌 최고 브랜드   위 올라
# 44               정무위 법안소위  삼성그룹 지배 구조 영향 삼성생명법  상정
# 45                나노 웨이퍼 가격     인상 삼성전자  반사이익 얻을까
# 46                  삼성 글로벌     위     올레드     위 지켰다
# 47         삼성                 유럽    기기 보안 표준 인증 획득
# 48        삼성  대한적십자사에  헌혈버스   대 전달    년간   대 지원 예정
# 49       삼성     억 기부  헌혈버스   대 전달     년간 헌혈 캠페인 지속
# 50      금융가 인사이드  고객 보험료로 지배구조 다지기  다시 도마 오른 삼성생명법
# 51             구글마저 넘었다 삼성전자  글로벌 브랜드  위 올라  뒷북비즈
# 52              삼성  아이폰에 낸드플래시 공급   적자  경쟁사 타격 불가피
# 53                        농협은행  삼성전자와 함께 김장김치 쌀 나눔
# 54                     삼성그룹 임원  상여금 십시일반으로 헌혈버스 지원
# 55                       에 과감히 투자해야 제  의 삼성전자 나온다
# 56  김경준 삼성전자 부사장      기술 규제 개선 환영  의료 로봇까지 생태계 확대
# 57            단독  삼성  스페인에 반도체 팹 짓나 경영진 내년  분기 유럽행
# 58                   특징주 삼성전자 하이닉스   안팎 상승  반도체 강세
#
#                                                 token  \
# 0      [삼성, 준, 법위, 사업, 지원, 회동, 콘트롤, 타워, 부활, 논의, 했, 나]
# 1            [삼성전자, 장애, 인, 직원, 채용, 자회사, 만든다, 일자리, 창출]
# 2                 [삼성전자, 자회사, 형, 장애, 인, 표준, 사업장, 만든다]
# 3                 [한국남, 동발, 전, 삼성전자, 탄소, 중립, 함께, 달린다]
# 4              [삼성, 임원, 들, 격려금, 억, 모아, 헌혈, 버스, 대, 기부]
# 5   [삼성전자, 찾, 은, 민주당, 기업, 미, 중, 패권, 희생양, 안, 되, 도록,...
# 6            [세계, 등, 한국, 제품, 몇, 개, 일까, 삼성전자, 가, 올, 킬]
# 7             [국내, 대, 기업, 내, 여성, 임원, 명, 돌파, 삼성전자, 최다]
# 8   [삼성, 대한, 적십자사, 에, 헌혈, 버스, 대, 기증, 이재용, 동행, 철학, 실천]
# 9                 [세계, 위, 면, 뭐, 하나, 창고, 에, 쌓이, 는, 삼성]
# 10                     [삼성, 저격, 삼성생명, 법, 년, 만, 의, 부활]
# 11         [세계, 에서, 팔린, 대, 중, 대, 는, 삼성, 누적, 점유, 율, 위]
# 12            [삼성전자, 식품, 관, 만, 방문, 기념, 고객, 감사, 기획, 전]
# 13    [품질, 경영, 대회, 은, 탑, 훈장, 에, 년, 위, 삼성전자, 김형남, 부사장]
# 14              [삼성, 글로벌, 점유, 율, 위, 는, 년, 연속, 왕좌, 예약]
# 15   [삼성전자, 메모리, 한파, 에, 세계, 반도체, 위, 자리, 인텔, 에, 내줬, 다]
# 16  [농협, 은행, 김치, 의, 날, 맞, 아, 삼성전자, 와, 김장, 및, 쌀, 나눔...
# 17        [번, 돈, 절반, 썼, 다, 삼성, 롯데, 대, 기업, 도, 줄줄이, 비명]
# 18        [민주, 삼성전자, 공장, 방문, 미, 중, 경쟁, 산업, 계, 전략, 점검]
# 19                   [삼성, 네오, 유럽, 기기, 보안, 표준, 인증, 획득]
# 20             [애플, 삼성전자, 낸드, 플래시, 도입, 가능, 성, 견제, 영향]
# 21                    [삼성, 경계현, 이, 주목, 한, 자이스, 억, 투자]
# 22        [민주당, 민생, 대책위, 반도체, 경쟁, 살얼음판, 삼성전자, 역할, 중요]
# 23  [삼성, 저격수, 박용진, 이, 발, 의, 한, 삼, 성생, 명법, 정무, 위, 법...
# 24                  [블랙, 프라이데이, 맞, 아, 삼성, 북미, 판촉, 사활]
# 25     [단독, 최고, 속도, 최저, 전력, 삼성전자, 년, 공들인, 차세대, 램, 공개]
# 26       [종합, 강세, 에, 도, 전, 세계, 휩쓴, 삼성, 점유, 율, 절반, 차지]
# 27            [믿, 었, 던, 서버, 용, 메모리, 마저, 삼성, 반도체, 혹한기]
# 28  [년, 더, 일, 했, 는데, 신입, 연봉, 이랑, 같, 다니, 삼성, 직원, 의,...
# 29               [반도체, 치킨, 게임, 삼성전자, 하이닉스, 왜, 달라지, 나]
# 30  [애플, 과, 경쟁, 와중, 에, 유럽, 서, 샤오미, 에, 추격, 당하, 는, 삼...
# 31   [삼성전자, 세계, 시장, 점유, 율, 로, 위, 수성, 프리미엄, 부문, 서, 선전]
# 32             [박용진, 삼성, 이재용, 아버지, 시대, 의, 유물, 정리, 해야]
# 33              [삼성, 경기, 침체, 에, 도, 글로벌, 시장, 점유, 율, 위]
# 34      [경제, 외치, 는, 민주, 삼성, 미, 중, 경쟁, 희생양, 않, 도록, 최선]
# 35     [삼성전자, 자회사, 형, 장애, 인, 표준, 사업장, 설립, 해, 일자리, 창출]
# 36          [파운드리, 반전, 신호탄, 쏜, 삼성, 거물급, 고객, 확보, 했, 다]
# 37            [다시, 등장, 한, 삼성생명, 법, 국회, 통과, 여부, 에, 주목]
# 38                     [남동, 발전, 삼성전자, 탄소, 중립, 공동, 대응]
# 39                       [불황, 덮친, 글로벌, 시장, 삼성, 는, 선전]
# 40                        [해묵, 은, 삼성생명, 법, 또, 꺼낸, 국회]
# 41                  [삼성, 년, 연속, 글로벌, 위, 수성, 도, 위, 유지]
# 42            [불황, 에, 도, 삼성, 전, 세계, 시장, 점유, 율, 위, 차지]
# 43             [삼성전자, 구글, 제치, 고, 글로벌, 최고, 브랜드, 위, 올라]
# 44     [정무, 위, 법안, 소위, 삼성그룹, 지배, 구조, 영향, 삼성생명, 법, 상정]
# 45             [나노, 웨이퍼, 가격, 인상, 삼성전자, 반사, 이익, 얻, 을까]
# 46                        [삼성, 글로벌, 위, 올레드, 위, 지켰, 다]
# 47                       [삼성, 유럽, 기기, 보안, 표준, 인증, 획득]
# 48  [삼성, 대한, 적십자사, 에, 헌혈, 버스, 대, 전달, 년, 간, 대, 지원, 예정]
# 49      [삼성, 억, 기부, 헌혈, 버스, 대, 전달, 년, 간, 헌혈, 캠페인, 지속]
# 50  [금융가, 인사이드, 고객, 보험료, 로, 지배, 구조, 다지기, 다시, 도마, 오...
# 51  [구글, 마저, 넘, 었, 다, 삼성전자, 글로벌, 브랜드, 위, 올라, 뒷, 북비...
# 52        [삼성, 아이폰, 에, 낸드, 플래시, 공급, 적자, 경쟁사, 타격, 불가피]
# 53               [농협, 은행, 삼성전자, 와, 함께, 김장, 김치, 쌀, 나눔]
# 54          [삼성그룹, 임원, 상여금, 십, 시, 일반, 으로, 헌혈, 버스, 지원]
# 55                  [에, 과감히, 투자, 해야, 제, 의, 삼성전자, 나온다]
# 56  [김경준, 삼성전자, 부사장, 기술, 규제, 개선, 환영, 의료, 로봇, 까지, 생...
# 57  [단독, 삼성, 스페인, 에, 반도체, 팹, 짓, 나, 경영진, 내년, 분기, 유럽...
# 58               [특징, 주, 삼성전자, 하이닉스, 안팎, 상승, 반도체, 강세]
#
#                                      remove_stopwords predict  \
# 0         [삼성, 준, 법위, 사업, 지원, 회동, 콘트롤, 타워, 부활, 논의, 나]       1
# 1               [삼성전자, 장애, 직원, 채용, 자회사, 만든다, 일자리, 창출]       0
# 2                    [삼성전자, 자회사, 형, 장애, 표준, 사업장, 만든다]       0
# 3                 [한국남, 동발, 전, 삼성전자, 탄소, 중립, 함께, 달린다]       1
# 4                 [삼성, 임원, 격려금, 억, 모아, 헌혈, 버스, 대, 기부]       0
# 5            [삼성전자, 찾, 민주당, 기업, 미, 중, 패권, 희생양, 안, 도록]       1
# 6                     [세계, 한국, 제품, 개, 일까, 삼성전자, 올, 킬]       1
# 7                [국내, 대, 기업, 내, 여성, 임원, 돌파, 삼성전자, 최다]       0
# 8          [삼성, 적십자사, 헌혈, 버스, 대, 기증, 이재용, 동행, 철학, 실천]       1
# 9                          [세계, 위, 뭐, 하나, 창고, 쌓이, 삼성]       0
# 10                              [삼성, 저격, 삼성생명, 법, 부활]       1
# 11                [세계, 팔린, 대, 중, 대, 삼성, 누적, 점유, 율, 위]       0
# 12               [삼성전자, 식품, 관, 방문, 기념, 고객, 감사, 기획, 전]       0
# 13             [품질, 경영, 대회, 탑, 훈장, 위, 삼성전자, 김형남, 부사장]       0
# 14                    [삼성, 글로벌, 점유, 율, 위, 연속, 왕좌, 예약]       0
# 15            [삼성전자, 메모리, 한파, 세계, 반도체, 위, 자리, 인텔, 내줬]       1
# 16        [농협, 은행, 김치, 날, 맞, 삼성전자, 김장, 쌀, 나눔, 행사, 실시]       0
# 17              [번, 돈, 절반, 썼, 삼성, 롯데, 대, 기업, 줄줄이, 비명]       1
# 18        [민주, 삼성전자, 공장, 방문, 미, 중, 경쟁, 산업, 계, 전략, 점검]       1
# 19                   [삼성, 네오, 유럽, 기기, 보안, 표준, 인증, 획득]       0
# 20             [애플, 삼성전자, 낸드, 플래시, 도입, 가능, 성, 견제, 영향]       0
# 21                          [삼성, 경계현, 주목, 자이스, 억, 투자]       0
# 22        [민주당, 민생, 대책위, 반도체, 경쟁, 살얼음판, 삼성전자, 역할, 중요]       0
# 23    [삼성, 저격수, 박용진, 발, 삼, 성생, 명법, 정무, 위, 법안, 소위, 상정]       1
# 24                     [블랙, 프라이데이, 맞, 삼성, 북미, 판촉, 사활]       0
# 25        [단독, 최고, 속도, 최저, 전력, 삼성전자, 공들인, 차세대, 램, 공개]       0
# 26             [종합, 강세, 전, 세계, 휩쓴, 삼성, 점유, 율, 절반, 차지]       1
# 27               [믿, 었, 서버, 용, 메모리, 마저, 삼성, 반도체, 혹한기]       2
# 28          [더, 일, 는데, 신입, 연봉, 이랑, 같, 다니, 삼성, 직원, 분노]       0
# 29               [반도체, 치킨, 게임, 삼성전자, 하이닉스, 왜, 달라지, 나]       0
# 30            [애플, 경쟁, 와중, 유럽, 서, 샤오미, 추격, 당하, 삼성, 폰]       1
# 31      [삼성전자, 세계, 시장, 점유, 율, 위, 수성, 프리미엄, 부문, 서, 선전]       1
# 32                [박용진, 삼성, 이재용, 아버지, 시대, 유물, 정리, 해야]       1
# 33                    [삼성, 경기, 침체, 글로벌, 시장, 점유, 율, 위]       0
# 34         [경제, 외치, 민주, 삼성, 미, 중, 경쟁, 희생양, 않, 도록, 최선]       1
# 35        [삼성전자, 자회사, 형, 장애, 표준, 사업장, 설립, 해, 일자리, 창출]       0
# 36                [파운드리, 반전, 신호탄, 쏜, 삼성, 거물급, 고객, 확보]       0
# 37                  [다시, 등장, 삼성생명, 법, 국회, 통과, 여부, 주목]       0
# 38                     [남동, 발전, 삼성전자, 탄소, 중립, 공동, 대응]       0
# 39                          [불황, 덮친, 글로벌, 시장, 삼성, 선전]       0
# 40                              [해묵, 삼성생명, 법, 꺼낸, 국회]       1
# 41                        [삼성, 연속, 글로벌, 위, 수성, 위, 유지]       0
# 42                  [불황, 삼성, 전, 세계, 시장, 점유, 율, 위, 차지]       1
# 43                [삼성전자, 구글, 제치, 글로벌, 최고, 브랜드, 위, 올라]       0
# 44     [정무, 위, 법안, 소위, 삼성그룹, 지배, 구조, 영향, 삼성생명, 법, 상정]       1
# 45             [나노, 웨이퍼, 가격, 인상, 삼성전자, 반사, 이익, 얻, 을까]       0
# 46                           [삼성, 글로벌, 위, 올레드, 위, 지켰]       0
# 47                       [삼성, 유럽, 기기, 보안, 표준, 인증, 획득]       0
# 48            [삼성, 적십자사, 헌혈, 버스, 대, 전달, 간, 대, 지원, 예정]       1
# 49         [삼성, 억, 기부, 헌혈, 버스, 대, 전달, 간, 헌혈, 캠페인, 지속]       0
# 50  [금융가, 인사이드, 고객, 보험료, 지배, 구조, 다지기, 다시, 도마, 오른, ...       1
# 51    [구글, 마저, 넘, 었, 삼성전자, 글로벌, 브랜드, 위, 올라, 뒷, 북비, 즈]       1
# 52           [삼성, 아이폰, 낸드, 플래시, 공급, 적자, 경쟁사, 타격, 불가피]       0
# 53                  [농협, 은행, 삼성전자, 함께, 김장, 김치, 쌀, 나눔]       0
# 54              [삼성그룹, 임원, 상여금, 십, 시, 일반, 헌혈, 버스, 지원]       1
# 55                        [과감히, 투자, 해야, 제, 삼성전자, 나온다]       1
# 56  [김경준, 삼성전자, 부사장, 기술, 규제, 개선, 환영, 의료, 로봇, 까지, 생...       0
# 57    [단독, 삼성, 스페인, 반도체, 팹, 짓, 나, 경영진, 내년, 분기, 유럽, 행]       0
# 58               [특징, 주, 삼성전자, 하이닉스, 안팎, 상승, 반도체, 강세]       1
#
#                       prob
# 0   41.81% 확률로 긍정 리뷰입니다.\n
# 1   95.52% 확률로 중성 리뷰입니다.\n
# 2   77.97% 확률로 중성 리뷰입니다.\n
# 3   51.40% 확률로 긍정 리뷰입니다.\n
# 4   43.82% 확률로 중성 리뷰입니다.\n
# 5   63.20% 확률로 긍정 리뷰입니다.\n
# 6   49.15% 확률로 긍정 리뷰입니다.\n
# 7   45.55% 확률로 중성 리뷰입니다.\n
# 8   37.74% 확률로 긍정 리뷰입니다.\n
# 9   70.09% 확률로 중성 리뷰입니다.\n
# 10  43.38% 확률로 긍정 리뷰입니다.\n
# 11  49.93% 확률로 중성 리뷰입니다.\n
# 12  62.57% 확률로 중성 리뷰입니다.\n
# 13  79.76% 확률로 중성 리뷰입니다.\n
# 14  53.49% 확률로 중성 리뷰입니다.\n
# 15  66.69% 확률로 긍정 리뷰입니다.\n
# 16  60.07% 확률로 중성 리뷰입니다.\n
# 17  48.44% 확률로 긍정 리뷰입니다.\n
# 18  44.49% 확률로 긍정 리뷰입니다.\n
# 19  87.71% 확률로 중성 리뷰입니다.\n
# 20  65.72% 확률로 중성 리뷰입니다.\n
# 21  40.86% 확률로 중성 리뷰입니다.\n
# 22  38.26% 확률로 중성 리뷰입니다.\n
# 23  56.50% 확률로 긍정 리뷰입니다.\n
# 24  65.18% 확률로 중성 리뷰입니다.\n
# 25  64.85% 확률로 중성 리뷰입니다.\n
# 26  66.05% 확률로 긍정 리뷰입니다.\n
# 27  44.77% 확률로 부정 리뷰입니다.\n
# 28  77.16% 확률로 중성 리뷰입니다.\n
# 29  83.60% 확률로 중성 리뷰입니다.\n
# 30  49.24% 확률로 긍정 리뷰입니다.\n
# 31  61.93% 확률로 긍정 리뷰입니다.\n
# 32  45.60% 확률로 긍정 리뷰입니다.\n
# 33  65.33% 확률로 중성 리뷰입니다.\n
# 34  51.91% 확률로 긍정 리뷰입니다.\n
# 35  77.33% 확률로 중성 리뷰입니다.\n
# 36  79.86% 확률로 중성 리뷰입니다.\n
# 37  49.35% 확률로 중성 리뷰입니다.\n
# 38  74.11% 확률로 중성 리뷰입니다.\n
# 39  78.39% 확률로 중성 리뷰입니다.\n
# 40  46.36% 확률로 긍정 리뷰입니다.\n
# 41  78.58% 확률로 중성 리뷰입니다.\n
# 42  68.90% 확률로 긍정 리뷰입니다.\n
# 43  66.42% 확률로 중성 리뷰입니다.\n
# 44  83.18% 확률로 긍정 리뷰입니다.\n
# 45  90.15% 확률로 중성 리뷰입니다.\n
# 46  63.63% 확률로 중성 리뷰입니다.\n
# 47  84.33% 확률로 중성 리뷰입니다.\n
# 48  61.71% 확률로 긍정 리뷰입니다.\n
# 49  75.03% 확률로 중성 리뷰입니다.\n
# 50  76.91% 확률로 긍정 리뷰입니다.\n
# 51  58.23% 확률로 긍정 리뷰입니다.\n
# 52  75.92% 확률로 중성 리뷰입니다.\n
# 53  48.88% 확률로 중성 리뷰입니다.\n
# 54  55.77% 확률로 긍정 리뷰입니다.\n
# 55  45.35% 확률로 긍정 리뷰입니다.\n
# 56  67.32% 확률로 중성 리뷰입니다.\n
# 57  83.01% 확률로 중성 리뷰입니다.\n
# 58  48.03% 확률로 긍정 리뷰입니다.\n

# %%
news_df[news_df['predict'] == 0]
# Out:
#                                              title  \
# 1                   삼성전자  장애인 직원 채용 자회사 만든다 일자리 창출
# 2                         삼성전자  자회사형 장애인 표준사업장 만든다
# 4                   삼성 임원들  격려금    억 모아 헌혈버스  대 기부
# 7               국내    대기업 내 여성 임원     명 돌파 삼성전자 최다
# 9                   세계    위면 뭐하나  창고에 쌓이는 삼성
# 11                세계에서 팔린     대 중  대는 삼성 누적 점유율  위
# 12               삼성전자   식품관     만 방문  기념 고객 감사 기획전
# 13             품질경영대회 은탑훈장에      년  위 삼성전자 김형남 부사장
# 14     삼성     글로벌 점유율  위     는   년 연속       왕좌  예약
# 16          농협은행   김치의 날  맞아 삼성전자와 김장 및 쌀 나눔 행사 실시
# 19          삼성 네오             유럽    기기 보안 표준 인증 획득
# 20                애플  삼성전자 낸드플래시 도입 가능성      견제 영향
# 21              삼성 경계현이 주목한 자이스       억         투자
# 22              민주당 민생대책위  반도체 경쟁 살얼음판 삼성전자 역할 중요
# 24                 블랙프라이데이 맞아 삼성     북미    판촉  사활
# 25     단독   최고 속도 최저 전력  삼성전자    년 공들인 차세대   램  공개
# 28                년 더 일했는데 신입 연봉이랑 같다니   삼성 직원의 분노
# 29                 반도체 치킨게임    삼성전자   하이닉스  왜 달라지나
# 33             삼성     경기 침체에도 글로벌    시장 점유율     위
# 35               삼성전자   자회사형 장애인 표준사업장  설립해 일자리 창출
# 36                  파운드리 반전 신호탄 쏜 삼성  거물급  고객 확보했다
# 37                   다시 등장한  삼성생명 법   국회 통과 여부에 주목
# 38                         남동발전 삼성전자   탄소중립  공동 대응
# 39                        불황 덮친 글로벌   시장 삼성   는 선전
# 41               삼성       년 연속 글로벌  위 수성   도  위 유지
# 43                 삼성전자  구글 제치고  글로벌 최고 브랜드   위 올라
# 45                나노 웨이퍼 가격     인상 삼성전자  반사이익 얻을까
# 46                  삼성 글로벌     위     올레드     위 지켰다
# 47         삼성                 유럽    기기 보안 표준 인증 획득
# 49       삼성     억 기부  헌혈버스   대 전달     년간 헌혈 캠페인 지속
# 52              삼성  아이폰에 낸드플래시 공급   적자  경쟁사 타격 불가피
# 53                        농협은행  삼성전자와 함께 김장김치 쌀 나눔
# 56  김경준 삼성전자 부사장      기술 규제 개선 환영  의료 로봇까지 생태계 확대
# 57            단독  삼성  스페인에 반도체 팹 짓나 경영진 내년  분기 유럽행
#
#                                                 token  \
# 1            [삼성전자, 장애, 인, 직원, 채용, 자회사, 만든다, 일자리, 창출]
# 2                 [삼성전자, 자회사, 형, 장애, 인, 표준, 사업장, 만든다]
# 4              [삼성, 임원, 들, 격려금, 억, 모아, 헌혈, 버스, 대, 기부]
# 7             [국내, 대, 기업, 내, 여성, 임원, 명, 돌파, 삼성전자, 최다]
# 9                 [세계, 위, 면, 뭐, 하나, 창고, 에, 쌓이, 는, 삼성]
# 11         [세계, 에서, 팔린, 대, 중, 대, 는, 삼성, 누적, 점유, 율, 위]
# 12            [삼성전자, 식품, 관, 만, 방문, 기념, 고객, 감사, 기획, 전]
# 13    [품질, 경영, 대회, 은, 탑, 훈장, 에, 년, 위, 삼성전자, 김형남, 부사장]
# 14              [삼성, 글로벌, 점유, 율, 위, 는, 년, 연속, 왕좌, 예약]
# 16  [농협, 은행, 김치, 의, 날, 맞, 아, 삼성전자, 와, 김장, 및, 쌀, 나눔...
# 19                   [삼성, 네오, 유럽, 기기, 보안, 표준, 인증, 획득]
# 20             [애플, 삼성전자, 낸드, 플래시, 도입, 가능, 성, 견제, 영향]
# 21                    [삼성, 경계현, 이, 주목, 한, 자이스, 억, 투자]
# 22        [민주당, 민생, 대책위, 반도체, 경쟁, 살얼음판, 삼성전자, 역할, 중요]
# 24                  [블랙, 프라이데이, 맞, 아, 삼성, 북미, 판촉, 사활]
# 25     [단독, 최고, 속도, 최저, 전력, 삼성전자, 년, 공들인, 차세대, 램, 공개]
# 28  [년, 더, 일, 했, 는데, 신입, 연봉, 이랑, 같, 다니, 삼성, 직원, 의,...
# 29               [반도체, 치킨, 게임, 삼성전자, 하이닉스, 왜, 달라지, 나]
# 33              [삼성, 경기, 침체, 에, 도, 글로벌, 시장, 점유, 율, 위]
# 35     [삼성전자, 자회사, 형, 장애, 인, 표준, 사업장, 설립, 해, 일자리, 창출]
# 36          [파운드리, 반전, 신호탄, 쏜, 삼성, 거물급, 고객, 확보, 했, 다]
# 37            [다시, 등장, 한, 삼성생명, 법, 국회, 통과, 여부, 에, 주목]
# 38                     [남동, 발전, 삼성전자, 탄소, 중립, 공동, 대응]
# 39                       [불황, 덮친, 글로벌, 시장, 삼성, 는, 선전]
# 41                  [삼성, 년, 연속, 글로벌, 위, 수성, 도, 위, 유지]
# 43             [삼성전자, 구글, 제치, 고, 글로벌, 최고, 브랜드, 위, 올라]
# 45             [나노, 웨이퍼, 가격, 인상, 삼성전자, 반사, 이익, 얻, 을까]
# 46                        [삼성, 글로벌, 위, 올레드, 위, 지켰, 다]
# 47                       [삼성, 유럽, 기기, 보안, 표준, 인증, 획득]
# 49      [삼성, 억, 기부, 헌혈, 버스, 대, 전달, 년, 간, 헌혈, 캠페인, 지속]
# 52        [삼성, 아이폰, 에, 낸드, 플래시, 공급, 적자, 경쟁사, 타격, 불가피]
# 53               [농협, 은행, 삼성전자, 와, 함께, 김장, 김치, 쌀, 나눔]
# 56  [김경준, 삼성전자, 부사장, 기술, 규제, 개선, 환영, 의료, 로봇, 까지, 생...
# 57  [단독, 삼성, 스페인, 에, 반도체, 팹, 짓, 나, 경영진, 내년, 분기, 유럽...
#
#                                      remove_stopwords predict  \
# 1               [삼성전자, 장애, 직원, 채용, 자회사, 만든다, 일자리, 창출]       0
# 2                    [삼성전자, 자회사, 형, 장애, 표준, 사업장, 만든다]       0
# 4                 [삼성, 임원, 격려금, 억, 모아, 헌혈, 버스, 대, 기부]       0
# 7                [국내, 대, 기업, 내, 여성, 임원, 돌파, 삼성전자, 최다]       0
# 9                          [세계, 위, 뭐, 하나, 창고, 쌓이, 삼성]       0
# 11                [세계, 팔린, 대, 중, 대, 삼성, 누적, 점유, 율, 위]       0
# 12               [삼성전자, 식품, 관, 방문, 기념, 고객, 감사, 기획, 전]       0
# 13             [품질, 경영, 대회, 탑, 훈장, 위, 삼성전자, 김형남, 부사장]       0
# 14                    [삼성, 글로벌, 점유, 율, 위, 연속, 왕좌, 예약]       0
# 16        [농협, 은행, 김치, 날, 맞, 삼성전자, 김장, 쌀, 나눔, 행사, 실시]       0
# 19                   [삼성, 네오, 유럽, 기기, 보안, 표준, 인증, 획득]       0
# 20             [애플, 삼성전자, 낸드, 플래시, 도입, 가능, 성, 견제, 영향]       0
# 21                          [삼성, 경계현, 주목, 자이스, 억, 투자]       0
# 22        [민주당, 민생, 대책위, 반도체, 경쟁, 살얼음판, 삼성전자, 역할, 중요]       0
# 24                     [블랙, 프라이데이, 맞, 삼성, 북미, 판촉, 사활]       0
# 25        [단독, 최고, 속도, 최저, 전력, 삼성전자, 공들인, 차세대, 램, 공개]       0
# 28          [더, 일, 는데, 신입, 연봉, 이랑, 같, 다니, 삼성, 직원, 분노]       0
# 29               [반도체, 치킨, 게임, 삼성전자, 하이닉스, 왜, 달라지, 나]       0
# 33                    [삼성, 경기, 침체, 글로벌, 시장, 점유, 율, 위]       0
# 35        [삼성전자, 자회사, 형, 장애, 표준, 사업장, 설립, 해, 일자리, 창출]       0
# 36                [파운드리, 반전, 신호탄, 쏜, 삼성, 거물급, 고객, 확보]       0
# 37                  [다시, 등장, 삼성생명, 법, 국회, 통과, 여부, 주목]       0
# 38                     [남동, 발전, 삼성전자, 탄소, 중립, 공동, 대응]       0
# 39                          [불황, 덮친, 글로벌, 시장, 삼성, 선전]       0
# 41                        [삼성, 연속, 글로벌, 위, 수성, 위, 유지]       0
# 43                [삼성전자, 구글, 제치, 글로벌, 최고, 브랜드, 위, 올라]       0
# 45             [나노, 웨이퍼, 가격, 인상, 삼성전자, 반사, 이익, 얻, 을까]       0
# 46                           [삼성, 글로벌, 위, 올레드, 위, 지켰]       0
# 47                       [삼성, 유럽, 기기, 보안, 표준, 인증, 획득]       0
# 49         [삼성, 억, 기부, 헌혈, 버스, 대, 전달, 간, 헌혈, 캠페인, 지속]       0
# 52           [삼성, 아이폰, 낸드, 플래시, 공급, 적자, 경쟁사, 타격, 불가피]       0
# 53                  [농협, 은행, 삼성전자, 함께, 김장, 김치, 쌀, 나눔]       0
# 56  [김경준, 삼성전자, 부사장, 기술, 규제, 개선, 환영, 의료, 로봇, 까지, 생...       0
# 57    [단독, 삼성, 스페인, 반도체, 팹, 짓, 나, 경영진, 내년, 분기, 유럽, 행]       0
#
#                       prob
# 1   95.52% 확률로 중성 리뷰입니다.\n
# 2   77.97% 확률로 중성 리뷰입니다.\n
# 4   43.82% 확률로 중성 리뷰입니다.\n
# 7   45.55% 확률로 중성 리뷰입니다.\n
# 9   70.09% 확률로 중성 리뷰입니다.\n
# 11  49.93% 확률로 중성 리뷰입니다.\n
# 12  62.57% 확률로 중성 리뷰입니다.\n
# 13  79.76% 확률로 중성 리뷰입니다.\n
# 14  53.49% 확률로 중성 리뷰입니다.\n
# 16  60.07% 확률로 중성 리뷰입니다.\n
# 19  87.71% 확률로 중성 리뷰입니다.\n
# 20  65.72% 확률로 중성 리뷰입니다.\n
# 21  40.86% 확률로 중성 리뷰입니다.\n
# 22  38.26% 확률로 중성 리뷰입니다.\n
# 24  65.18% 확률로 중성 리뷰입니다.\n
# 25  64.85% 확률로 중성 리뷰입니다.\n
# 28  77.16% 확률로 중성 리뷰입니다.\n
# 29  83.60% 확률로 중성 리뷰입니다.\n
# 33  65.33% 확률로 중성 리뷰입니다.\n
# 35  77.33% 확률로 중성 리뷰입니다.\n
# 36  79.86% 확률로 중성 리뷰입니다.\n
# 37  49.35% 확률로 중성 리뷰입니다.\n
# 38  74.11% 확률로 중성 리뷰입니다.\n
# 39  78.39% 확률로 중성 리뷰입니다.\n
# 41  78.58% 확률로 중성 리뷰입니다.\n
# 43  66.42% 확률로 중성 리뷰입니다.\n
# 45  90.15% 확률로 중성 리뷰입니다.\n
# 46  63.63% 확률로 중성 리뷰입니다.\n
# 47  84.33% 확률로 중성 리뷰입니다.\n
# 49  75.03% 확률로 중성 리뷰입니다.\n
# 52  75.92% 확률로 중성 리뷰입니다.\n
# 53  48.88% 확률로 중성 리뷰입니다.\n
# 56  67.32% 확률로 중성 리뷰입니다.\n
# 57  83.01% 확률로 중성 리뷰입니다.\n

# %%
news_df[news_df['predict'] == 1]
# Out:
#                                           title  \
# 0               삼성 준법위 사업지원    회동 콘트롤타워 부활 논의했나
# 3                    한국남동발전 삼성전자   탄소중립  함께 달린다
# 5        삼성전자 찾은 민주당   기업  미 중 패권 희생양 안되도록 할 것
# 6                    세계  등 한국제품 몇개일까  삼성전자가 올킬
# 8       삼성  대한적십자사에  헌혈버스   대 기증 이재용  동행 철학  실천
# 10                    삼성  저격  삼성생명법    년 만의 부활
# 15           삼성전자  메모리 한파에 세계 반도체  위 자리 인텔에 내줬다
# 17            번 돈 절반 썼다  삼성    롯데 대기업도 줄줄이  비명
# 18               민주  삼성전자 공장 방문 미중 경쟁 산업계 전략 점검
# 23         삼성 저격수  박용진이 발의한  삼성생명법  정무위 법안소위 상정
# 26   종합    강세에도 전 세계 휩쓴        삼성     점유율 절반 차지
# 30                애플과 경쟁 와중에 유럽서 샤오미에 추격당하는 삼성폰
# 31  삼성전자  세계    시장 점유율    로  위 수성  프리미엄 부문서 선전
# 32                박용진  삼성 이재용  아버지 시대의 유물 정리해야
# 34           경제  외치는 민주  삼성   미중 경쟁 희생양 않도록 최선
# 40                          해묵은  삼성생명법  또 꺼낸 국회
# 42               불황에도 삼성     전 세계 시장점유율    위 차지
# 44            정무위 법안소위  삼성그룹 지배 구조 영향 삼성생명법  상정
# 48     삼성  대한적십자사에  헌혈버스   대 전달    년간   대 지원 예정
# 50   금융가 인사이드  고객 보험료로 지배구조 다지기  다시 도마 오른 삼성생명법
# 51          구글마저 넘었다 삼성전자  글로벌 브랜드  위 올라  뒷북비즈
# 54                  삼성그룹 임원  상여금 십시일반으로 헌혈버스 지원
# 55                    에 과감히 투자해야 제  의 삼성전자 나온다
# 58                특징주 삼성전자 하이닉스   안팎 상승  반도체 강세
#
#                                                 token  \
# 0      [삼성, 준, 법위, 사업, 지원, 회동, 콘트롤, 타워, 부활, 논의, 했, 나]
# 3                 [한국남, 동발, 전, 삼성전자, 탄소, 중립, 함께, 달린다]
# 5   [삼성전자, 찾, 은, 민주당, 기업, 미, 중, 패권, 희생양, 안, 되, 도록,...
# 6            [세계, 등, 한국, 제품, 몇, 개, 일까, 삼성전자, 가, 올, 킬]
# 8   [삼성, 대한, 적십자사, 에, 헌혈, 버스, 대, 기증, 이재용, 동행, 철학, 실천]
# 10                     [삼성, 저격, 삼성생명, 법, 년, 만, 의, 부활]
# 15   [삼성전자, 메모리, 한파, 에, 세계, 반도체, 위, 자리, 인텔, 에, 내줬, 다]
# 17        [번, 돈, 절반, 썼, 다, 삼성, 롯데, 대, 기업, 도, 줄줄이, 비명]
# 18        [민주, 삼성전자, 공장, 방문, 미, 중, 경쟁, 산업, 계, 전략, 점검]
# 23  [삼성, 저격수, 박용진, 이, 발, 의, 한, 삼, 성생, 명법, 정무, 위, 법...
# 26       [종합, 강세, 에, 도, 전, 세계, 휩쓴, 삼성, 점유, 율, 절반, 차지]
# 30  [애플, 과, 경쟁, 와중, 에, 유럽, 서, 샤오미, 에, 추격, 당하, 는, 삼...
# 31   [삼성전자, 세계, 시장, 점유, 율, 로, 위, 수성, 프리미엄, 부문, 서, 선전]
# 32             [박용진, 삼성, 이재용, 아버지, 시대, 의, 유물, 정리, 해야]
# 34      [경제, 외치, 는, 민주, 삼성, 미, 중, 경쟁, 희생양, 않, 도록, 최선]
# 40                        [해묵, 은, 삼성생명, 법, 또, 꺼낸, 국회]
# 42            [불황, 에, 도, 삼성, 전, 세계, 시장, 점유, 율, 위, 차지]
# 44     [정무, 위, 법안, 소위, 삼성그룹, 지배, 구조, 영향, 삼성생명, 법, 상정]
# 48  [삼성, 대한, 적십자사, 에, 헌혈, 버스, 대, 전달, 년, 간, 대, 지원, 예정]
# 50  [금융가, 인사이드, 고객, 보험료, 로, 지배, 구조, 다지기, 다시, 도마, 오...
# 51  [구글, 마저, 넘, 었, 다, 삼성전자, 글로벌, 브랜드, 위, 올라, 뒷, 북비...
# 54          [삼성그룹, 임원, 상여금, 십, 시, 일반, 으로, 헌혈, 버스, 지원]
# 55                  [에, 과감히, 투자, 해야, 제, 의, 삼성전자, 나온다]
# 58               [특징, 주, 삼성전자, 하이닉스, 안팎, 상승, 반도체, 강세]
#
#                                      remove_stopwords predict  \
# 0         [삼성, 준, 법위, 사업, 지원, 회동, 콘트롤, 타워, 부활, 논의, 나]       1
# 3                 [한국남, 동발, 전, 삼성전자, 탄소, 중립, 함께, 달린다]       1
# 5            [삼성전자, 찾, 민주당, 기업, 미, 중, 패권, 희생양, 안, 도록]       1
# 6                     [세계, 한국, 제품, 개, 일까, 삼성전자, 올, 킬]       1
# 8          [삼성, 적십자사, 헌혈, 버스, 대, 기증, 이재용, 동행, 철학, 실천]       1
# 10                              [삼성, 저격, 삼성생명, 법, 부활]       1
# 15            [삼성전자, 메모리, 한파, 세계, 반도체, 위, 자리, 인텔, 내줬]       1
# 17              [번, 돈, 절반, 썼, 삼성, 롯데, 대, 기업, 줄줄이, 비명]       1
# 18        [민주, 삼성전자, 공장, 방문, 미, 중, 경쟁, 산업, 계, 전략, 점검]       1
# 23    [삼성, 저격수, 박용진, 발, 삼, 성생, 명법, 정무, 위, 법안, 소위, 상정]       1
# 26             [종합, 강세, 전, 세계, 휩쓴, 삼성, 점유, 율, 절반, 차지]       1
# 30            [애플, 경쟁, 와중, 유럽, 서, 샤오미, 추격, 당하, 삼성, 폰]       1
# 31      [삼성전자, 세계, 시장, 점유, 율, 위, 수성, 프리미엄, 부문, 서, 선전]       1
# 32                [박용진, 삼성, 이재용, 아버지, 시대, 유물, 정리, 해야]       1
# 34         [경제, 외치, 민주, 삼성, 미, 중, 경쟁, 희생양, 않, 도록, 최선]       1
# 40                              [해묵, 삼성생명, 법, 꺼낸, 국회]       1
# 42                  [불황, 삼성, 전, 세계, 시장, 점유, 율, 위, 차지]       1
# 44     [정무, 위, 법안, 소위, 삼성그룹, 지배, 구조, 영향, 삼성생명, 법, 상정]       1
# 48            [삼성, 적십자사, 헌혈, 버스, 대, 전달, 간, 대, 지원, 예정]       1
# 50  [금융가, 인사이드, 고객, 보험료, 지배, 구조, 다지기, 다시, 도마, 오른, ...       1
# 51    [구글, 마저, 넘, 었, 삼성전자, 글로벌, 브랜드, 위, 올라, 뒷, 북비, 즈]       1
# 54              [삼성그룹, 임원, 상여금, 십, 시, 일반, 헌혈, 버스, 지원]       1
# 55                        [과감히, 투자, 해야, 제, 삼성전자, 나온다]       1
# 58               [특징, 주, 삼성전자, 하이닉스, 안팎, 상승, 반도체, 강세]       1
#
#                       prob
# 0   41.81% 확률로 긍정 리뷰입니다.\n
# 3   51.40% 확률로 긍정 리뷰입니다.\n
# 5   63.20% 확률로 긍정 리뷰입니다.\n
# 6   49.15% 확률로 긍정 리뷰입니다.\n
# 8   37.74% 확률로 긍정 리뷰입니다.\n
# 10  43.38% 확률로 긍정 리뷰입니다.\n
# 15  66.69% 확률로 긍정 리뷰입니다.\n
# 17  48.44% 확률로 긍정 리뷰입니다.\n
# 18  44.49% 확률로 긍정 리뷰입니다.\n
# 23  56.50% 확률로 긍정 리뷰입니다.\n
# 26  66.05% 확률로 긍정 리뷰입니다.\n
# 30  49.24% 확률로 긍정 리뷰입니다.\n
# 31  61.93% 확률로 긍정 리뷰입니다.\n
# 32  45.60% 확률로 긍정 리뷰입니다.\n
# 34  51.91% 확률로 긍정 리뷰입니다.\n
# 40  46.36% 확률로 긍정 리뷰입니다.\n
# 42  68.90% 확률로 긍정 리뷰입니다.\n
# 44  83.18% 확률로 긍정 리뷰입니다.\n
# 48  61.71% 확률로 긍정 리뷰입니다.\n
# 50  76.91% 확률로 긍정 리뷰입니다.\n
# 51  58.23% 확률로 긍정 리뷰입니다.\n
# 54  55.77% 확률로 긍정 리뷰입니다.\n
# 55  45.35% 확률로 긍정 리뷰입니다.\n
# 58  48.03% 확률로 긍정 리뷰입니다.\n

# %%
news_df[news_df['predict'] == 2]
# Out:
#                                title                                    token  \
# 27   믿었던 서버용 메모리마저   삼성     반도체 혹한기   [믿, 었, 던, 서버, 용, 메모리, 마저, 삼성, 반도체, 혹한기]
#
#                         remove_stopwords predict                    prob
# 27  [믿, 었, 서버, 용, 메모리, 마저, 삼성, 반도체, 혹한기]       2  44.77% 확률로 부정 리뷰입니다.\n
